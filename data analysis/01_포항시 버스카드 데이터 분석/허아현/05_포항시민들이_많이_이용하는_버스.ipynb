# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rc('font', family='Malgun Gothic')

# %%
file_path = './data/df_new_final.csv'
df_cp = pd.read_csv(file_path)
df_cp
# Out:
#                   승차시각            하차시각  노선명                   노선설명 승객연령 환승여부  \
# 0       20200104051524  20200104052439  131         양덕-송도-시청-양학-양덕   일반    N
# 1       20200104051607  20200104053502  500      문덕-시외터미널-흥해-청하-월포   일반    N
# 2       20200104051838  20200104052941  102  문덕-남구청-고속터미널-북구보건소-양덕   일반    N
# 3       20200104052127  20200104052430  200        양덕-남구청(야구장)-구룡포  청소년    N
# 4       20200104052229  20200104053228  108      양덕-죽도-양학-시청-유강-지곡   일반    N
# ...                ...             ...  ...                    ...  ...  ...
# 842603  20200103234051  20200103234410  107        문덕-시외(고속)터미널-흥해   일반    N
# 842604  20200103234140  20200103234229  109       양덕-시외터미널-위덕대(유강)   일반    Y
# 842605  20200103234616  20200103235557  102  문덕-남구청-고속터미널-북구보건소-양덕   일반    N
# 842606  20200103234845  20200104000712  108      양덕-죽도-양학-시청-유강-지곡   일반    N
# 842607  20200103234927  20200103235821  109       양덕-시외터미널-위덕대(유강)   일반    N
#
#        추가운임여부     승차정류장  승차정류장 GPS X  승차정류장 GPS Y    하차정류장  하차정류장 GPS X  \
# 0           N     양덕차고지   129.401693    36.077258     죽도시장   129.365486
# 1           N     문덕사거리   129.403442    35.962846  시외버스터미널   129.350580
# 2           N    준양주택3차   129.403063    35.960871   청림초등학교   129.405275
# 3           N  환호해맞이그린빌   129.392404    36.068838  두호동주민센터   129.378910
# 4           N    장량휴먼시아   129.383462    36.090800   두호초등학교   129.371202
# ...       ...       ...          ...          ...      ...          ...
# 842603      N    도심환승센터   129.365165    36.043435     죽도시장   129.365486
# 842604      N   대동우방아파트   129.360148    36.050620  동아화성아파트   129.356090
# 842605      N      대도교회   129.356060    36.009820    우리유치원   129.410930
# 842606      N   우방신천지타운   129.370103    36.058736    경성홈타운   129.385980
# 842607      N    장성초등학교   129.372370    36.068290    상지프라자   129.393115
#
#         하차정류장 GPS Y
# 0         36.034110
# 1         36.013250
# 2         35.993257
# 3         36.060370
# 4         36.064088
# ...             ...
# 842603    36.034110
# 842604    36.051290
# 842605    35.982500
# 842606    36.077010
# 842607    36.081740
#
# [842608 rows x 13 columns]

# %%
df = df_cp.copy()
df
# Out:
#                   승차시각            하차시각  노선명                   노선설명 승객연령 환승여부  \
# 0       20200104051524  20200104052439  131         양덕-송도-시청-양학-양덕   일반    N
# 1       20200104051607  20200104053502  500      문덕-시외터미널-흥해-청하-월포   일반    N
# 2       20200104051838  20200104052941  102  문덕-남구청-고속터미널-북구보건소-양덕   일반    N
# 3       20200104052127  20200104052430  200        양덕-남구청(야구장)-구룡포  청소년    N
# 4       20200104052229  20200104053228  108      양덕-죽도-양학-시청-유강-지곡   일반    N
# ...                ...             ...  ...                    ...  ...  ...
# 842603  20200103234051  20200103234410  107        문덕-시외(고속)터미널-흥해   일반    N
# 842604  20200103234140  20200103234229  109       양덕-시외터미널-위덕대(유강)   일반    Y
# 842605  20200103234616  20200103235557  102  문덕-남구청-고속터미널-북구보건소-양덕   일반    N
# 842606  20200103234845  20200104000712  108      양덕-죽도-양학-시청-유강-지곡   일반    N
# 842607  20200103234927  20200103235821  109       양덕-시외터미널-위덕대(유강)   일반    N
#
#        추가운임여부     승차정류장  승차정류장 GPS X  승차정류장 GPS Y    하차정류장  하차정류장 GPS X  \
# 0           N     양덕차고지   129.401693    36.077258     죽도시장   129.365486
# 1           N     문덕사거리   129.403442    35.962846  시외버스터미널   129.350580
# 2           N    준양주택3차   129.403063    35.960871   청림초등학교   129.405275
# 3           N  환호해맞이그린빌   129.392404    36.068838  두호동주민센터   129.378910
# 4           N    장량휴먼시아   129.383462    36.090800   두호초등학교   129.371202
# ...       ...       ...          ...          ...      ...          ...
# 842603      N    도심환승센터   129.365165    36.043435     죽도시장   129.365486
# 842604      N   대동우방아파트   129.360148    36.050620  동아화성아파트   129.356090
# 842605      N      대도교회   129.356060    36.009820    우리유치원   129.410930
# 842606      N   우방신천지타운   129.370103    36.058736    경성홈타운   129.385980
# 842607      N    장성초등학교   129.372370    36.068290    상지프라자   129.393115
#
#         하차정류장 GPS Y
# 0         36.034110
# 1         36.013250
# 2         35.993257
# 3         36.060370
# 4         36.064088
# ...             ...
# 842603    36.034110
# 842604    36.051290
# 842605    35.982500
# 842606    36.077010
# 842607    36.081740
#
# [842608 rows x 13 columns]

# %%
# 월, 일, 시 컬럼 추가
df['승차월'] = df['승차시각'].astype(str).str[4:6]
df['승차일'] = df['승차시각'].astype(str).str[6:8]
df['승차시'] = df['승차시각'].astype(str).str[8:10]

# %%
df['노선명'].value_counts()
# Out:
# 105           103383
# 107            88222
# 102            85243
# 101            79500
# 200            59264
#                ...
# 동해지선(금광)           6
# 흥해공영(교도소)          6
# 청하지선(죽도시장)         3
# 176(6회)            1
# 흥해공영(용덕)           1
# Name: 노선명, Length: 83, dtype: int64

# %%
'''
가장 많이 이용하는 버스번호는 105번, 107번, 102번, 101번, 200번이다.
'''

# %%
top_bus = ['105','107','102','101','200']

# %%
df_top_bus_en = pd.DataFrame()
df_top_bus_ex = pd.DataFrame()

# %%
for i in top_bus:
    df_en = df[df['노선명'] == i]['승차정류장'].value_counts()[0:1]
    df_top_bus_en = pd.concat([df_top_bus_en, df_en])
    
for i in top_bus:
    df_ex = df[df['노선명'] == i]['하차정류장'].value_counts()[0:1]
    df_top_bus_ex = pd.concat([df_top_bus_ex, df_ex])

# %%
# 포항 시민들이 가장 많이 이용하는 버스번호 top5의 가장 많이 탑승하는 승차정류장
df_top_bus_en
# Out:
#                0
# 시외버스터미널  13883.0
# 흥해환승센터    7405.0
# 죽도시장      4165.0
# 풍림아이원     5650.0
# 시외버스터미널   9871.0

# %%
# 포항 시민들이 가장 많이 이용하는 버스번호 top5의 가장 많이 하차하는 하차정류장
df_top_bus_ex
# Out:
#                0
# 죽도시장     21235.0
# 시외버스터미널  14643.0
# 죽도시장     14010.0
# 죽도시장     17379.0
# 시외버스터미널  10653.0

# %%
시외버스 터미널과 죽도시장을 이용하는 승객이 많다

# %%
df_top_bus = pd.DataFrame()

# %%
for i in top_bus:
    df_temp = df[df['노선명'] == i]
    df_top_bus = pd.concat([df_top_bus, df_temp], ignore_index=True)
    
df_top_bus
# Out:
#                   승차시각            하차시각  노선명             노선설명 승객연령 환승여부 추가운임여부  \
# 0       20200104054521  20200104060753  105      양덕-시외터미널-지곡   일반    N      N
# 1       20200104054727  20200104060127  105      양덕-시외터미널-지곡   일반    N      N
# 2       20200104054803  20200104060252  105      양덕-시외터미널-지곡   일반    N      N
# 3       20200104054840  20200104055257  105      양덕-시외터미널-지곡   일반    N      N
# 4       20200104054843  20200104060305  105      양덕-시외터미널-지곡   일반    N      N
# ...                ...             ...  ...              ...  ...  ...    ...
# 415607  20200103224520  20200103231227  200  양덕-남구청(야구장)-구룡포   일반    N      N
# 415608  20200103225620  20200103231107  200  양덕-남구청(야구장)-구룡포   일반    N      N
# 415609  20200103225736  20200103230203  200  양덕-남구청(야구장)-구룡포   일반    N      N
# 415610  20200103230806  20200103231552  200  양덕-남구청(야구장)-구룡포   일반    N      N
# 415611  20200103232057  20200103232759  200  양덕-남구청(야구장)-구룡포   일반    N      N
#
#           승차정류장  승차정류장 GPS X  승차정류장 GPS Y      하차정류장  하차정류장 GPS X  \
# 0       포항테크노파크   129.315820    36.031720       죽도시장   129.365169
# 1       포항테크노파크   129.315820    36.031720       교보생명   129.352500
# 2         럭키아파트   129.379190    36.065110        북구청   129.367128
# 3         롯데백화점   129.371083    36.048872       죽도시장   129.365717
# 4        장성럭키2차   129.378880    36.067050        북구청   129.367128
# ...         ...          ...          ...        ...          ...
# 415607  구룡포환승센터   129.556133    35.990988    시외버스터미널   129.350580
# 415608   동해면사무소   129.440228    35.988834  뱃머리 평생학습원   129.354538
# 415609     포항세관   129.371880    36.051450       홈플러스   129.364714
# 415610  시외버스터미널   129.350290    36.013280      남구보건소   129.396855
# 415611    청림삼거리   129.402648    35.994424    시외버스터미널   129.350580
#
#         하차정류장 GPS Y 승차월 승차일 승차시
# 0         36.035704  01  04  05
# 1         36.015568  01  04  05
# 2         36.041941  01  04  05
# 3         36.033299  01  04  05
# 4         36.041941  01  04  05
# ...             ...  ..  ..  ..
# 415607    36.013250  01  03  22
# 415608    36.009020  01  03  22
# 415609    36.031262  01  03  22
# 415610    35.992624  01  03  23
# 415611    36.013250  01  03  23
#
# [415612 rows x 16 columns]

# %%
df_month = df_top_bus.pivot_table(values='승객연령',
                       index='노선명',
                       columns='승차월',
                       aggfunc='count')

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df_month, annot=True, fmt='.0f', cmap='rocket_r')
plt.title('월별 및 버스노선별 탑승객')
plt.show()

# %%
df_day = df_top_bus.pivot_table(values='승객연령',
                       index='노선명',
                       columns='승차일',
                       aggfunc='count')

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df_day, annot=True, fmt='.0f', cmap='rocket_r')
plt.title('일별 및 버스노선별 탑승객')
plt.show()

# %%
df_hour = df_top_bus.pivot_table(values='승객연령',
                       index='노선명',
                       columns='승차시',
                       aggfunc='count')
df_hour = df_hour.fillna(0)

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df_hour, annot=True, fmt='.0f', cmap='rocket_r')
plt.title('시간별 및 버스노선별 탑승객')
plt.show()
